# %%
from sys import path

path.append("../../")

# %%
from lib_crypto.b5.Note_Shenon import main

main()
# Out:
#  Тест на пословице и тексте
# {'alph': 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'}
#  Шифровка пословицы : [30, 9, 18, 23, 3, 22, 19, 10, 11, 1, 32, 24, 10, 7, 31, 27, 0, 26, 1,
# 28, 13, 6, 19, 10, 18, 19, 2, 15, 15, 29, 10, 28, 1, 9, 18, 30, 10, 18, 0, 26, 20, 17, 8, 17,
# 31, 31, 32, 4, 6, 3, 22, 20, 1, 25, 3, 24, 16]
#  Расшифровка пословицы : тотзптктохочетестьяйцазптдолженпримиритьсяскудахтаньемтчк
#  Шифровка 1000 : [29, 9, 1, 32, 25, 16, 13, 5, 10, 7, 22, 19, 10, 10, 7, 24, 26, 12, 5, 27,
# 32, 10, 26, 12, 18, 24, 23, 15, 17, 10, 29, 23, 32, 3, 20, 8, 10, 24, 16, 11, 1, 26, 6, 25,
# 2, 13, 14, 17, 15, 4, 25, 24, 10, 26, 12, 10, 19, 21, 6, 18, 23, 11, 16, 0, 25, 6, 1, 3, 14,
# 29, 1, 31, 18, 7, 16, 31, 13, 16, 22, 26, 30, 25, 29, 9, 2, 21, 23, 11, 30, 8, 4, 23, 20, 5,
# 17, 9, 5, 25, 12, 5, 23, 4, 8, 27, 29, 31, 30, 2, 28, 6, 23, 3, 7, 15, 10, 12, 17, 9, 11, 27,
# 3, 2, 10, 7, 11, 28, 16, 17, 0, 11, 32, 28, 31, 12, 11, 30, 22, 12, 18, 24, 7, 31, 26, 2, 14,
# ...
